# %%
import signac
import numpy as np
project = signac.get_project()

# %%
sub = project.find_jobs({
    "sp.pdbID": {"$in": ['8SBD']},
})
sub
# Out:
# JobsCursor(project=Project('/panfs/accrepfs.vampire/data/yang_lab/nehilpkd/biomatsims/smd/fibril'), filter={'sp.pdbID': {'$in': ['8SBD']}})

# %%
pdbs = ['8SBD']

statepoint = {
    "replicate" : 5,
    "fiberverse_directory": "/data/yang_lab/nehilpkd/fibrilverse_rcsb", 
    "type": "single", 
    "pull_chains": [0, -1], 
    "pull_constant": 1000, 
    "pull_steps": 250000, 
    "pull_rate": 0.01
}
statepoints = []
for pdb in pdbs:
    statepoint["pdbID"] = pdb
    statepoints.append(statepoint.copy())
if __name__ == "__main__":
    if not project.doc.get("response_table"):
        project.doc["response_table"] = {}

    for sp in statepoints:
        if "pull_rate" not in sp:
            sp["pull_rate"] = 0.01
        if "pull_constant" not in sp:
            sp["pull_constant"] = 1000
        if "pull_steps" not in sp:
            sp["pull_steps"] = 250000
        if sp['pdbID'] == '7YPG':
            sp['protofibril_distance_threshold'] = 8.0
        else:
            sp['protofibril_distance_threshold'] = 20.0

    for sp in statepoints:
        if not project.find_jobs(sp):
            print("Initializing job", sp)
            project.open_job(sp).init()
            print(project.find_jobs(sp))
# Out:
# Initializing job {'replicate': 5, 'fiberverse_directory': '/data/yang_lab/nehilpkd/fibrilverse_rcsb', 'type': 'single', 'pull_chains': [0, -1], 'pull_constant': 1000, 'pull_steps': 250000, 'pull_rate': 0.01, 'pdbID': '8SBD', 'protofibril_distance_threshold': 20.0}
# JobsCursor(project=Project('/panfs/accrepfs.vampire/data/yang_lab/nehilpkd/biomatsims/smd/fibril'), filter={'replicate': 5, 'fiberverse_directory': '/data/yang_lab/nehilpkd/fibrilverse_rcsb', 'type': 'single', 'pull_chains': [0, -1], 'pull_constant': 1000, 'pull_steps': 250000, 'pull_rate': 0.01, 'pdbID': '8SBD', 'protofibril_distance_threshold': 20.0})

# %%
# Find jobs matching the query
for job in project.find_jobs({"sp.pdbID": {"$in": ['8SBD']},}):
    # Run the job
    job.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 # Find jobs matching the query
#       2 for job in project.find_jobs({"sp.pdbID": {"$in": ['8SBD']},}):
#       3     # Run the job
# ----> 4     job.run()
#
# AttributeError: 'Job' object has no attribute 'run'
